# %% [markdown]
# # My jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Daniel Serrano Jiménez** <br>
# Aerospace Software Developer

# %% [markdown]
# *I am interested in Data Science because we coud use its predictive power to develop space trash retrieval programs within my company.*

# %% [markdown]
# ### Substraction of two numbers

# %%
25-10
# Out:
# 15

# %% [markdown]
# ________
#
# * This is a bulleted list
# * of two elements
# ________
# 1. this is a numbered list
# 2. of two elements
# ________
# > This is a blocked quote
